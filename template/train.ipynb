# %% [markdown]
# # train.ipynb
# This notebook contains the training code for a small language model using the TRL (Transformer Reinforcement Learning) library.
#
# We'll be training a decoder-only (GPT-2 style) model with a custom configuration and using the DebertaV2 tokenizer provided in the data folder.

# %% [markdown]
# ## Installation
# First, we need to install the required dependencies for training:

# %%
# %pip install transformers trl bitsandbytes tf-keras
# %pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.4.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.4)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.73.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.8.2)
# Requirement already satisfied: pillow in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (10.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.0.0)
# Requirement already satisfied: namex in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tbhro\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\tbhro\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from transformers import set_seed
from transformers import AutoConfig, AutoModelForCausalLM, DebertaV2Tokenizer
from trl import SFTTrainer, SFTConfig
from datasets import load_dataset
import torch
import os

# Force CPU usage
os.environ["CUDA_VISIBLE_DEVICES"] = ""
torch.cuda.is_available = lambda: False

def preprocess_logits_for_metrics(logits, labels):
    """Extract predicted token IDs from model logits for evaluation"""
    pred_ids = torch.argmax(logits, dim=-1)  # Get the token with highest probability
    return pred_ids


def compute_metrics(eval_pred):
    """Calculate accuracy by comparing predictions with true labels"""
    logits, labels = eval_pred
    predictions = logits.flatten()  # Flatten to 1D array
    labels = labels.flatten()
    
    # Only consider non-padding tokens (labels != -100 are actual tokens)
    mask = labels != -100
    labels = labels[mask]
    predictions = predictions[mask]

    # Calculate accuracy
    correct = labels == predictions
    accuracy = correct.sum() / float(len(correct))
    return {"acc": accuracy}

# %%
# Load the custom tokenizer trained on BabyLM dataset
model_name = "openai-community/gpt2"
tokenizer = DebertaV2Tokenizer('data/tokenizer.model')

# Create custom configuration based on GPT-2 but with smaller dimensions
config = AutoConfig.from_pretrained(model_name)
config.hidden_size = 384 # Same dimensionality as the best performing BabyLM model.
config.intermediate_size = 1280  # Feed-forward intermediate size
config.vocab_size = tokenizer.vocab_size  # Match tokenizer vocabulary size

# Initialize model with custom configuration
model = AutoModelForCausalLM.from_config(config)

# Print model size for reference, should be around 31M parameters
num_params = sum(p.numel() for p in model.parameters())
print(f"Number of model parameters: {num_params}")

# Load training and validation datasets
dataset = load_dataset('text', data_files = {'train': 'data/train.txt', 'validation': 'data/dev.txt'})
print(dataset)

# %%
# Set random seed for reproducibility
set_seed(0)

# Initialize SFTTrainer with comprehensive configuration
trainer = SFTTrainer(
    model = model,
    processing_class = tokenizer,  # Tokenizer for text processing
    train_dataset = dataset['train'],
    eval_dataset = dataset['validation'],
    preprocess_logits_for_metrics=preprocess_logits_for_metrics,
    compute_metrics=compute_metrics,
    args = SFTConfig(
        # Data processing
        remove_unused_columns = True,
        label_names = ["labels"],
        dataset_num_proc = 12,  # Number of processes for dataset preprocessing
        packing = True,  # Pack multiple sequences into single training example
        eval_packing = True,
        max_length = 64,  # Maximum sequence length
        dataset_text_field = "text",
        
        # Training strategy
        eval_strategy = "steps",
        per_device_train_batch_size = 64, # how many sequences to process at once
        gradient_accumulation_steps = 1, # how many batches to process before updating the model. Effectively increases the batch size without increasing memory usage.
        warmup_ratio = 0.05,  # 5% of training steps for learning rate increase from 0to 2e-4
        num_train_epochs = 10,
        learning_rate = 2e-4,
        
        # Optimization and precision - CPU only settings
        use_cpu = True,  # Force CPU usage
        fp16 = False,  # Disable FP16 (not supported on CPU)
        bf16 = False,  # Disable BF16
        optim = "adamw_torch",  # Use standard PyTorch AdamW (8bit not available on CPU)
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",  # Cosine learning rate schedule
        max_grad_norm=1,  # Gradient clipping
        
        # Logging and evaluation
        logging_steps = 10,
        eval_steps = 100,
        save_steps = 100,
        eval_accumulation_steps=1, # how many evaluation batches to accumulate on GPU. 
        include_for_metrics=[],
        
        # Reproducibility and output
        seed = 0,
        # output_dir = "",  # Uncomment to specify output directory
        report_to = "none",  # Disable wandb/tensorboard logging
    ),
)

# Start training
trainer.train()
